# %% [markdown]
# ### Requirements:
#
# * **pyautogui**
#
# **Pyautogui** is an awesome library that helps us perform automation task. To install it run: ` pip install pyautogui `
#
# *Note: These requirments are staged for version 1.0.0*
